# %%
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np

iris_X, iris_y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(iris_X, iris_y, test_size = 0.2, random_state=123)
iris = sns.load_dataset("iris")
grafic = sns.pairplot(iris, hue="species")

# %%
lr_model = LogisticRegression(max_iter=400)
lr_fit = lr_model.fit(X_train,y_train)
lr_prediction = lr_fit.predict(X_test)
lr_metric = metrics.accuracy_score(lr_prediction,y_test)
pd.DataFrame(metrics.confusion_matrix(y_test,lr_prediction, labels=[0,1,2]),
             columns=['Setosa_predicted','Versicolor_predicted','Virginica_predicted'],
             index=['Setosa_original','Versicolor_original','Virginica_original'])
# Out:
#                      Setosa_predicted  Versicolor_predicted  \
# Setosa_original                    13                     0
# Versicolor_original                 0                     6
# Virginica_original                  0                     0
#
#                      Virginica_predicted
# Setosa_original                        0
# Versicolor_original                    0
# Virginica_original                    11

# %%
result = pd.DataFrame(X_test)
result['target'] = lr_prediction
result.head(10)
# Out:
#      0    1    2    3  target
# 0  6.3  2.5  4.9  1.5       1
# 1  6.8  3.0  5.5  2.1       2
# 2  6.4  2.8  5.6  2.2       2
# 3  5.6  3.0  4.1  1.3       1
# 4  4.9  3.6  1.4  0.1       0
# 5  6.0  3.0  4.8  1.8       2
# 6  6.3  2.3  4.4  1.3       1
# 7  4.4  3.2  1.3  0.2       0
# 8  4.4  2.9  1.4  0.2       0
# 9  5.5  2.6  4.4  1.2       1

# %%
plt.plot(lr_prediction)
plt.show()
plt.plot(y_test,color='b')
plt.show()

# %%
sns.pairplot(result,hue='target')
